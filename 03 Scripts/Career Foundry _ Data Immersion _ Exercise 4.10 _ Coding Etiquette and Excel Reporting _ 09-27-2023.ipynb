# %% [markdown]
# # Importations

# %%
# Import Libraries 

import pandas as pd 
import numpy as np 
import os

# %%
# Set Path 

path = r'C:\Users\calli\OneDrive\Data Immersion\Achievement 4'

# %%
# Import orders_products_customers_merged_2 pickle file as 

ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_customers_merged_2.pkl'))

# %% [markdown]
# # Exercise Functions

# %% [markdown]
# ## Crosstab

# %%
# Show dataframe head

ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#    ... average_prices  spending_flag  median_days_since_prior_order  \
# ...

# %%
# Create a crosstab

crosstab = pd.crosstab(ords_prods_merge['days_since_prior_order'], ords_prods_merge['order_number'], dropna = False)

# %%
# Show crosstab head

crosstab.head()
# Out:
# order_number            1      2      3      4      5      6      7      8   \
# days_since_prior_order
# 0.0                      0  20536  20441  17984  16438  16046  14384  13890
# 1.0                      0  31674  29950  28010  27092  25533  24996  22921
# 2.0                      0  46454  46264  43902  40729  40907  38101  37519
# 3.0                      0  61637  63388  59996  57882  56183  52869  49291
# 4.0                      0  76733  78861  73540  70519  66569  62399  61143
#
# order_number               9      10  ...    90    91    92    93    94    95  \
# days_since_prior_order                ...
# 0.0                     12774  11460  ...  1195  1148  1040   937  1134  1099
# 1.0                     21783  21067  ...  2787  2801  2728  2605  2606  2639
# 2.0                     35745  33830  ...  3623  3555  3314  3589  3319  3072
# 3.0                     48295  47826  ...  3318  3237  2799  3073  2902  2635
# ...

# %%
# Copy crosstab to clipboard

crosstab.to_clipboard()

# %% [markdown]
# ## Python Text Editor

# %%
# show columns

ords_prods_merge.columns
# Out:
# Index(['order_id', 'user_id', 'order_number', 'order_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', '_merge', 'product_name', 'aisle_id',
#        'department_id', 'prices', 'price_label', 'busiest_day', 'busiest_days',
#        'busiest_period_of_day', 'max_order', 'loyalty_flag', 'average_prices',
#        'spending_flag', 'median_days_since_prior_order', 'frequency_flag',
#        'gender', 'state', 'age', 'dependants', 'family_status', 'income'],
#       dtype='object')

# %%
# Turn column names into list 

col = ords_prods_merge.columns.to_list()

# %%
# show col_list output

col_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_day_of_week',
#  'order_hour_of_day',
#  'days_since_prior_order',
#  'product_id',
#  'add_to_cart_order',
#  'reordered',
#  '_merge',
#  'product_name',
#  'aisle_id',
#  'department_id',
#  'prices',
#  'price_label',
#  'busiest_day',
#  'busiest_days',
#  'busiest_period_of_day',
#  'max_order',
#  'loyalty_flag',
#  'average_prices',
#  'spending_flag',
#  'median_days_since_prior_order',
#  'frequency_flag',
#  'gender',
#  'state',
#  'age',
#  'dependants',
#  'family_status',
#  'income']

# %%
# Copy col_list

col.to_clipboard()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 3
#       1 # Copy col_list
# ----> 3 col.to_clipboard()
#
# AttributeError: 'list' object has no attribute 'to_clipboard'

# %%
# Turn col into dataframe to copy to clipboard

pd.DataFrame(col).to_clipboard(index=False, header=False)
