# %% [markdown]
# # Task 4.9: Part 1

# %% [markdown]
# ## Question 3: Importations

# %%
# Import Analysis Libraries 

import pandas as pd 
import numpy as np 
import os

# %%
# Set Path 

path = r'C:\Users\calli\OneDrive\Data Immersion\Achievement 4'

# %%
# Import customer data set as cust

cust = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers.csv'), index_col = False)

# %% [markdown]
# ## Question 4: Wrangle the data

# %%
# Show dataframe head

cust.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# ### Rename columns to make them uniform

# %%
# Rename "First Name" to "first_name" 

cust.rename(columns = {'First Name': 'first_name'}, inplace = True)

# %%
# Rename "Surnam" to "last_name"

cust.rename(columns = {'Surnam': 'last_name'}, inplace = True)

# %%
# Rename "Gender" to "gender"

cust.rename(columns = {'Gender': 'gender'}, inplace = True)

# %%
# Rename "STATE" to "state"

cust.rename(columns = {'STATE': 'state'}, inplace = True)

# %%
# Rename "Age" to "age"

cust.rename(columns = {'Age': 'age'}, inplace = True)

# %%
# Rename "fam_status" to "marital_status"

cust.rename(columns = {'fam_status': 'marital_status'}, inplace = True)

# %%
# Rename "marital_status" to "family_status"

cust.rename(columns = {'marital_status': 'family_status'}, inplace = True)

# %%
# Rename "n_dependants" to "dependants"

cust.rename(columns = {'n_dependants': 'dependants'}, inplace = True)

# %%
# Show dataframe

cust
# Out:
#         user_id first_name last_name  gender           state  age date_joined  \
# 0         26711    Deborah  Esquivel  Female        Missouri   48    1/1/2017
# 1         33890   Patricia      Hart  Female      New Mexico   36    1/1/2017
# 2         65803    Kenneth    Farley    Male           Idaho   35    1/1/2017
# 3        125935   Michelle     Hicks  Female            Iowa   40    1/1/2017
# 4        130797        Ann   Gilmore  Female        Maryland   26    1/1/2017
# ...         ...        ...       ...     ...             ...  ...         ...
# 206204   168073       Lisa      Case  Female  North Carolina   44    4/1/2020
# 206205    49635     Jeremy   Robbins    Male          Hawaii   62    4/1/2020
# 206206   135902      Doris  Richmond  Female        Missouri   66    4/1/2020
# 206207    81095       Rose   Rollins  Female      California   27    4/1/2020
# 206208    80148    Cynthia     Noble  Female        New York   55    4/1/2020
#
# ...

# %% [markdown]
# ### Check Data Types

# %%
# Check data types of all columns

cust.dtypes
# Out:
# user_id           int64
# first_name       object
# last_name        object
# gender           object
# state            object
# age               int64
# date_joined      object
# n_dependants      int64
# family_status    object
# income            int64
# dtype: object

# %% [markdown]
# ### Check variable counts

# %%
# Check family_status flag counts

cust['family_status'].value_counts(dropna = False)
# Out:
# family_status
# married                             144906
# single                               33962
# divorced/widowed                     17640
# living with parents and siblings      9701
# Name: count, dtype: int64

# %%
# Check state counts

cust['state'].value_counts(dropna = False)
# Out:
# state
# Florida                 4044
# Colorado                4044
# Illinois                4044
# Alabama                 4044
# District of Columbia    4044
# Hawaii                  4044
# Arizona                 4044
# Connecticut             4044
# California              4044
# Indiana                 4044
# Arkansas                4044
# Alaska                  4044
# Delaware                4044
# Iowa                    4044
# Idaho                   4044
# Georgia                 4044
# Wyoming                 4043
# Mississippi             4043
# Oklahoma                4043
# Utah                    4043
# New Hampshire           4043
# Kentucky                4043
# Maryland                4043
# Rhode Island            4043
# Massachusetts           4043
# Michigan                4043
# New Jersey              4043
# Kansas                  4043
# South Dakota            4043
# Minnesota               4043
# Tennessee               4043
# New York                4043
# ...

# %%
# Check gender counts

cust['gender'].value_counts(dropna = False)
# Out:
# gender
# Male      104067
# Female    102142
# Name: count, dtype: int64

# %%
# Check dependant counts

cust['dependants'].value_counts(dropna = False)
# Out:
# dependants
# 0    51602
# 3    51594
# 1    51531
# 2    51482
# Name: count, dtype: int64

# %%
# Check date_joined counts

cust['date_joined'].value_counts(dropna = False)
# Out:
# date_joined
# 9/17/2018     213
# 2/10/2018     212
# 4/1/2019      211
# 9/21/2019     211
# 12/19/2017    210
#              ...
# 9/1/2018      141
# 1/22/2018     140
# 11/24/2017    139
# 7/18/2019     138
# 8/6/2018      128
# Name: count, Length: 1187, dtype: int64

# %% [markdown]
# ### Check Statistics

# %%
cust.describe()
# Out:
#              user_id            age     dependants         income
# count  206209.000000  206209.000000  206209.000000  206209.000000
# mean   103105.000000      49.501646       1.499823   94632.852548
# std     59527.555167      18.480962       1.118433   42473.786988
# min         1.000000      18.000000       0.000000   25903.000000
# 25%     51553.000000      33.000000       0.000000   59874.000000
# 50%    103105.000000      49.000000       1.000000   93547.000000
# 75%    154657.000000      66.000000       3.000000  124244.000000
# max    206209.000000      81.000000       3.000000  593901.000000

# %% [markdown]
# ### Remove irrelivent columns

# %%
# Show dataframe head

cust.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    dependants family_status  income
# 0           3       married  165665
# 1           0        single   59285
# 2           2       married   99568
# 3           0        single   42049
# 4           1       married   40374

# %%
# Create subset without customer names

cust_2 = cust[['user_id', 'gender', 'state', 'age', 'dependants', 'family_status', 'income']]

# %%
# Show cust_2 head

cust_2.head()
# Out:
#    user_id  gender       state  age  dependants family_status  income
# 0    26711  Female    Missouri   48           3       married  165665
# 1    33890  Female  New Mexico   36           0        single   59285
# 2    65803    Male       Idaho   35           2       married   99568
# 3   125935  Female        Iowa   40           0        single   42049
# 4   130797  Female    Maryland   26           1       married   40374

# %% [markdown]
# ## Question 5: Data quality and consistency checks

# %%
# Check for missing values

cust_2.isnull().sum()
# Out:
# user_id          0
# gender           0
# state            0
# age              0
# dependants       0
# family_status    0
# income           0
# dtype: int64

# %%
# Create a subset identifying dupicates

cust_2_dup = cust_2[cust_2.duplicated()]

# %%
# Show duplicate subset

cust_2_dup
# Out:
# Empty DataFrame
# Columns: [user_id, gender, state, age, dependants, family_status, income]
# Index: []

# %%
# Check data types of all columns

cust_2.dtypes
# Out:
# user_id           int64
# gender           object
# state            object
# age               int64
# dependants        int64
# family_status    object
# income            int64
# dtype: object

# %% [markdown]
# ## Questions 6: Combine with rest of prepared data

# %%
# Import orders_products_merged_4 dataframe

df_clean = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_4.pkl'))

# %%
# Show df_clean head

df_clean.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#    ...        price_label     busiest_day    busiest_days  \
# ...

# %%
# merge cust_2 with df_clean using user_id column

df_merged = df_clean.merge(cust_2, on = 'user_id')

# %%
# Show merged dataframe head

df_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#    ... average_prices  spending_flag  median_days_since_prior_order  \
# ...

# %%
# Check merged shape

df_merged.shape
# Out:
# (32404859, 30)

# %%
# Check cust_2 shape

cust_2.shape
# Out:
# (206209, 7)

# %%
# Check df_clean shape

df_clean.shape
# Out:
# (32404859, 24)

# %%
# Check merged statistics

df_merged.describe()
# Out:
#            order_id       user_id  order_number  order_day_of_week  \
# count  3.240486e+07  3.240486e+07  3.240486e+07       3.240486e+07
# mean   1.710745e+06  1.029372e+05  1.714230e+01       2.738867e+00
# std    9.872988e+05  5.946610e+04  1.753532e+01       2.090077e+00
# min    2.000000e+00  1.000000e+00  1.000000e+00       0.000000e+00
# 25%    8.559470e+05  5.142200e+04  5.000000e+00       1.000000e+00
# 50%    1.711049e+06  1.026160e+05  1.100000e+01       3.000000e+00
# 75%    2.565499e+06  1.543890e+05  2.400000e+01       5.000000e+00
# max    3.421083e+06  2.062090e+05  9.900000e+01       6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.240486e+07            3.032876e+07  3.240486e+07
# mean        1.342515e+01            1.110408e+01  2.559866e+04
# std         4.246380e+00            8.779064e+00  1.408400e+04
# min         0.000000e+00            0.000000e+00  1.000000e+00
# ...

# %%
df_merged.describe('order_id')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 df_merged.describe('order_id')
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:10819, in NDFrame.describe(self, percentiles, include, exclude)
#   10577 @final
#   10578 def describe(
#   10579     self: NDFrameT,
#    (...)
#   10582     exclude=None,
#   10583 ) -> NDFrameT:
#   10584     """
#   10585     Generate descriptive statistics.
#   10586
#    (...)
#   10817     max            NaN      3.0
#   10818     """
# > 10819     return describe_ndframe(
#   10820         obj=self,
#   10821         include=include,
#   10822         exclude=exclude,
#   10823         percentiles=percentiles,
#   10824     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\methods\describe.py:80, in describe_ndframe(obj, include, exclude, percentiles)
#      52 def describe_ndframe(
# ...

# %%
display.precision: pd.set_option('precision', 5)
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 display.precision: pd.set_option('precision', 5)
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:261, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     260 def __call__(self, *args, **kwds) -> T:
# --> 261     return self.__func__(*args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:156, in _set_option(*args, **kwargs)
#     153     raise TypeError(f'_set_option() got an unexpected keyword argument "{kwarg}"')
#     155 for k, v in zip(args[::2], args[1::2]):
# --> 156     key = _get_single_key(k, silent)
#     158     o = _get_registered_option(key)
#     159     if o and o.validator:
#
# File ~\anaconda3\Lib\site-packages\pandas\_config\config.py:123, in _get_single_key(pat, silent)
#     121     raise OptionError(f"No such keys(s): {repr(pat)}")
# ...

# %%
# Format statistics

df_merged.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#              order_id         user_id    order_number order_day_of_week  \
# count  32404859.00000  32404859.00000  32404859.00000    32404859.00000
# mean    1710745.49743    102937.22876        17.14230           2.73887
# std      987298.83401     59466.10434        17.53532           2.09008
# min           2.00000         1.00000         1.00000           0.00000
# 25%      855947.00000     51422.00000         5.00000           1.00000
# 50%     1711049.00000    102616.00000        11.00000           3.00000
# 75%     2565499.00000    154389.00000        24.00000           5.00000
# max     3421083.00000    206209.00000        99.00000           6.00000
#
#       order_hour_of_day days_since_prior_order      product_id  \
# count    32404859.00000         30328763.00000  32404859.00000
# mean           13.42515               11.10408     25598.66174
# std             4.24638                8.77906     14083.99635
# min             0.00000                0.00000         1.00000
# ...

# %%
# Format statistics with 2 decimels instead of 5

df_merged.describe().apply(lambda s: s.apply('{0:.2f}'.format))
# Out:
#           order_id      user_id order_number order_day_of_week  \
# count  32404859.00  32404859.00  32404859.00       32404859.00
# mean    1710745.50    102937.23        17.14              2.74
# std      987298.83     59466.10        17.54              2.09
# min           2.00         1.00         1.00              0.00
# 25%      855947.00     51422.00         5.00              1.00
# 50%     1711049.00    102616.00        11.00              3.00
# 75%     2565499.00    154389.00        24.00              5.00
# max     3421083.00    206209.00        99.00              6.00
#
#       order_hour_of_day days_since_prior_order   product_id add_to_cart_order  \
# count       32404859.00            30328763.00  32404859.00       32404859.00
# mean              13.43                  11.10     25598.66              8.35
# std                4.25                   8.78     14084.00              7.13
# min                0.00                   0.00         1.00              1.00
# ...

# %% [markdown]
# ## Question 8: Export new dataframe

# %%
# Export data to pkl 

df_merged.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_customers_merged_2.pkl'))
